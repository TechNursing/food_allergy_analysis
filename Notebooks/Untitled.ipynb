# %%
import pandas as pd

allergy_data = pd.read_csv('../Data/food-allergy-analysis-Zenodo.csv')
display(allergy_data.head(10))
# Out:
#    SUBJECT_ID  BIRTH_YEAR GENDER_FACTOR   RACE_FACTOR   ETHNICITY_FACTOR  \
# 0           1        2006   S1 - Female    R1 - Black  E0 - Non-Hispanic
# 1           2        1994   S1 - Female    R0 - White  E0 - Non-Hispanic
# 2           3        2006     S0 - Male    R0 - White      E1 - Hispanic
# 3           4        2004     S0 - Male  R4 - Unknown      E1 - Hispanic
# 4           5        2006   S1 - Female    R1 - Black  E0 - Non-Hispanic
# 5           6        2006     S0 - Male    R0 - White  E0 - Non-Hispanic
# 6           7        2006   S1 - Female    R0 - White  E0 - Non-Hispanic
# 7           8        2006   S1 - Female    R1 - Black  E0 - Non-Hispanic
# 8           9        2006     S0 - Male    R0 - White  E0 - Non-Hispanic
# 9          10        2006   S1 - Female    R1 - Black  E0 - Non-Hispanic
#
#         PAYER_FACTOR  ATOPIC_MARCH_COHORT  AGE_START_YEARS  AGE_END_YEARS  \
# 0      P1 - Medicaid                False         0.093087       3.164956
# ...

# %%
allergy_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 333200 entries, 0 to 333199
# Data columns (total 50 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   SUBJECT_ID               333200 non-null  int64
#  1   BIRTH_YEAR               333200 non-null  int64
#  2   GENDER_FACTOR            333200 non-null  object
#  3   RACE_FACTOR              333200 non-null  object
#  4   ETHNICITY_FACTOR         333200 non-null  object
#  5   PAYER_FACTOR             333200 non-null  object
#  6   ATOPIC_MARCH_COHORT      333200 non-null  bool
#  7   AGE_START_YEARS          333200 non-null  float64
#  8   AGE_END_YEARS            333200 non-null  float64
#  9   SHELLFISH_ALG_START      5246 non-null    float64
#  10  SHELLFISH_ALG_END        1051 non-null    float64
#  11  FISH_ALG_START           1796 non-null    float64
#  12  FISH_ALG_END             527 non-null     float64
# ...

# %%
allergy_data.head().T
# Out:
#                                          0                  1  \
# SUBJECT_ID                               1                  2
# BIRTH_YEAR                            2006               1994
# GENDER_FACTOR                  S1 - Female        S1 - Female
# RACE_FACTOR                     R1 - Black         R0 - White
# ETHNICITY_FACTOR         E0 - Non-Hispanic  E0 - Non-Hispanic
# PAYER_FACTOR                 P1 - Medicaid  P0 - Non-Medicaid
# ATOPIC_MARCH_COHORT                  False              False
# AGE_START_YEARS                   0.093087          12.232717
# AGE_END_YEARS                     3.164956          18.880219
# SHELLFISH_ALG_START                    NaN                NaN
# SHELLFISH_ALG_END                      NaN                NaN
# FISH_ALG_START                         NaN                NaN
# FISH_ALG_END                           NaN                NaN
# MILK_ALG_START                         NaN                NaN
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import japanize_matplotlib

sns.set_theme(font_scale=1.5, font='IPAexGothic')

# %%
# 全体のアレルギーの分布
def addlabels(x,y):
    for i in range(len(x)):
        plt.text(i, y[i], y[i], ha = 'center', va = 'bottom', c = 'Magenta')


plt.figure(figsize=(16, 7))
x=['SHELL FISH', 'FISH ALG', 'MILK_ALG', 'SOY_ALG', 'EGG_ALG', 'WHEAT_ALG', 'PEANUT_ALG',
   'SESAME_ALG', 'TREENUT_ALG', 'WALNUT_ALG', 'PECAN_ALG', 'PISTACH_ALG', 'ALMOND_ALG',
   'BRAZIL_ALG', 'HAZELNUT_ALG', 'CASHEW_ALG', 'ATOPIC_DERM', 'ALLERGIC_RHINITIS', 'ASTHMA']
height=[
    allergy_data["SHELLFISH_ALG_START"].count(),allergy_data["FISH_ALG_START"].count(),
    allergy_data["MILK_ALG_START"].count(),allergy_data["SOY_ALG_START"].count(),
    allergy_data["EGG_ALG_START"].count(),allergy_data["WHEAT_ALG_START"].count(),
    allergy_data["PEANUT_ALG_START"].count(),allergy_data["SESAME_ALG_START"].count(),
    allergy_data["TREENUT_ALG_START"].count(),allergy_data["WALNUT_ALG_START"].count(),
    allergy_data["PECAN_ALG_START"].count(),allergy_data["PISTACH_ALG_START"].count(),
    allergy_data["ALMOND_ALG_START"].count(),allergy_data["BRAZIL_ALG_START"].count(),
    allergy_data["HAZELNUT_ALG_START"].count(),allergy_data["CASHEW_ALG_START"].count(),
    allergy_data["ATOPIC_DERM_START"].count(),allergy_data["ALLERGIC_RHINITIS_START"].count(),
    allergy_data["ASTHMA_START"].count()]
plt.bar(x=x, height=height)

addlabels(x, height)
plt.xticks(rotation=60)
plt.title('Number of allergy cases', fontsize=18)
plt.box(True)
# results_path = './Graphs/Number of allergy cases.png'
# plt.savefig(results_path, bbox_inches='tight')
plt.show()

# %%
### 分析結果

黒人が全割合で有病率が高い。

保険の種類による有病率の分析結果より、低所得保険者が多いことから劣悪な生活環境にある可能性も考えられる。

アジア人はアトピー性皮膚炎は多いが、他はそこまで高くない。

白人に関しては鼻炎や喘息の症状が皮膚炎より多く、喘息に関しては1.5倍の比率である。

# %%
# 人種別が見やすいようにクレンジング
allergy_data['RACE_FACTOR'] = allergy_data['RACE_FACTOR'].str.split()
allergy_data['RACE_FACTOR'] = allergy_data['RACE_FACTOR'].str[2]
display(allergy_data['RACE_FACTOR'].head(10))
# Out:
# 0      Black
# 1      White
# 2      White
# 3    Unknown
# 4      Black
# 5      White
# 6      White
# 7      Black
# 8      White
# 9      Black
# Name: RACE_FACTOR, dtype: object

# %%
# 人種の分布
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20,12))

sns.countplot(x=allergy_data['RACE_FACTOR'], ax=ax1,
              order=allergy_data['RACE_FACTOR'].value_counts().index).set(title='Amount of data for each race')

allergy_data['RACE_FACTOR'].value_counts().plot.pie(counterclock = False, autopct = '%1.1f%%', pctdistance=.6,
                                                    startangle = 90, radius=1, ax=ax2).set(title='Racial Percentage')
# results_path = '../Graphs/Racial Percentage.png'
# plt.savefig(results_path, bbox_inches='tight')
plt.show()

# %%
# 分析結果
# 白人のデータが最多
# 人種のデータ量に偏りあるため、それぞれの人種ごとに分析した方が良さそう

# %%
# sns.countplot(y=atopic, hue=allergy_data['RACE_FACTOR'],
#               order=allergy_data['RACE_FACTOR'].value_counts().index)

# %%
# 男女の比率
sns.countplot(y=allergy_data['RACE_FACTOR'], hue=allergy_data['GENDER_FACTOR'],
              hue_order = ['S0 - Male', 'S1 - Female'], order=allergy_data['RACE_FACTOR'].value_counts().index)
# results_path = '../Graphs/gender_gap.png'
# plt.savefig(results_path, bbox_inches='tight')
# Out:
# <Axes: xlabel='count', ylabel='RACE_FACTOR'>

# %%
# 分析結果
# 男女比はほぼ無し

# %%
# アトピックマーチと他の変数との相関関係

# %%
# クレンジング、plotしやすい様に型をfloatからstrへ変換
allergy_data["ATOPIC_MARCH_COHORT"] = allergy_data["ATOPIC_MARCH_COHORT"].astype(str)
print(allergy_data["ATOPIC_MARCH_COHORT"].dtype)
# Out:
# object

# %%
# ATOPIC_MARCH_COHORTをダミー変数化
allergy_data["ATOPIC_MARCH_COHORT"] = allergy_data["ATOPIC_MARCH_COHORT"].str.replace('False', '0').str.replace('True', '1')
allergy_data["ATOPIC_MARCH_COHORT"] = allergy_data["ATOPIC_MARCH_COHORT"].astype(int)
display(allergy_data.head(10))
# Out:
#    SUBJECT_ID  BIRTH_YEAR GENDER_FACTOR RACE_FACTOR   ETHNICITY_FACTOR  \
# 0           1        2006   S1 - Female       Black  E0 - Non-Hispanic
# 1           2        1994   S1 - Female       White  E0 - Non-Hispanic
# 2           3        2006     S0 - Male       White      E1 - Hispanic
# 3           4        2004     S0 - Male     Unknown      E1 - Hispanic
# 4           5        2006   S1 - Female       Black  E0 - Non-Hispanic
# 5           6        2006     S0 - Male       White  E0 - Non-Hispanic
# 6           7        2006   S1 - Female       White  E0 - Non-Hispanic
# 7           8        2006   S1 - Female       Black  E0 - Non-Hispanic
# 8           9        2006     S0 - Male       White  E0 - Non-Hispanic
# 9          10        2006   S1 - Female       Black  E0 - Non-Hispanic
#
#         PAYER_FACTOR  ATOPIC_MARCH_COHORT  AGE_START_YEARS  AGE_END_YEARS  \
# 0      P1 - Medicaid                    0         0.093087       3.164956
# ...

# %%
age_time = pd.get_dummies(allergy_data, columns=['被害者の年齢', '発生時（始期）'], prefix_sep='/')

# %%
# 各アレルギーの上位3位をダミー化
# allergy_3 = pd.get_dummies(allergy_data,columns=['ATOPIC_DERM_START','ALLERGIC_RHINITIS_START','ASTHMA_START'])
# display(allergy_3.head(10))
