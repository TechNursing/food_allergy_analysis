# %%
import pandas as pd

allergy_data = pd.read_csv('../Data/food-allergy-analysis-Zenodo.csv')
display(allergy_data.head(10))
allergy_data.dtypes
# Out:
#    SUBJECT_ID  BIRTH_YEAR GENDER_FACTOR   RACE_FACTOR   ETHNICITY_FACTOR  \
# 0           1        2006   S1 - Female    R1 - Black  E0 - Non-Hispanic
# 1           2        1994   S1 - Female    R0 - White  E0 - Non-Hispanic
# 2           3        2006     S0 - Male    R0 - White      E1 - Hispanic
# 3           4        2004     S0 - Male  R4 - Unknown      E1 - Hispanic
# 4           5        2006   S1 - Female    R1 - Black  E0 - Non-Hispanic
# 5           6        2006     S0 - Male    R0 - White  E0 - Non-Hispanic
# 6           7        2006   S1 - Female    R0 - White  E0 - Non-Hispanic
# 7           8        2006   S1 - Female    R1 - Black  E0 - Non-Hispanic
# 8           9        2006     S0 - Male    R0 - White  E0 - Non-Hispanic
# 9          10        2006   S1 - Female    R1 - Black  E0 - Non-Hispanic
#
#         PAYER_FACTOR  ATOPIC_MARCH_COHORT  AGE_START_YEARS  AGE_END_YEARS  \
# 0      P1 - Medicaid                False         0.093087       3.164956
# 1  P0 - Non-Medicaid                False        12.232717      18.880219
# 2  P0 - Non-Medicaid                 True         0.010951       6.726899
# 3  P0 - Non-Medicaid                False         2.398357       9.111567
# 4  P0 - Non-Medicaid                False         0.013689       6.193018
# 5      P1 - Medicaid                False         0.087611       4.958248
# 6  P0 - Non-Medicaid                False         0.010951       6.677618
# 7  P0 - Non-Medicaid                 True         0.032854       6.286105
# 8  P0 - Non-Medicaid                 True         0.019165       6.726899
# 9      P1 - Medicaid                 True         0.021903       6.275154
#
#    SHELLFISH_ALG_START  ...  CASHEW_ALG_END  ATOPIC_DERM_START  \
# 0                  NaN  ...             NaN                NaN
# 1                  NaN  ...             NaN                NaN
# 2                  NaN  ...             NaN           4.884326
# 3                  NaN  ...             NaN                NaN
# 4                  NaN  ...             NaN                NaN
# 5                  NaN  ...             NaN                NaN
# 6                  NaN  ...             NaN                NaN
# 7                  NaN  ...             NaN                NaN
# 8                  NaN  ...             NaN           1.015743
# 9                  NaN  ...             NaN                NaN
#
#    ATOPIC_DERM_END  ALLERGIC_RHINITIS_START  ALLERGIC_RHINITIS_END  \
# 0              NaN                      NaN                    NaN
# 1              NaN                      NaN                    NaN
# 2              NaN                 3.917864               6.157426
# 3              NaN                      NaN                    NaN
# 4              NaN                      NaN                    NaN
# 5              NaN                      NaN                    NaN
# 6              NaN                      NaN                    NaN
# 7              NaN                      NaN                    NaN
# 8         1.015743                      NaN                    NaN
# 9              NaN                      NaN                    NaN
#
#    ASTHMA_START  ASTHMA_END  FIRST_ASTHMARX  LAST_ASTHMARX  NUM_ASTHMARX
# 0           NaN         NaN             NaN            NaN           NaN
# 1           NaN         NaN       12.262834      18.880219           2.0
# 2      5.127995         NaN        1.404517       6.157426           4.0
# 3           NaN         NaN             NaN            NaN           NaN
# 4           NaN         NaN             NaN            NaN           NaN
# 5           NaN         NaN             NaN            NaN           NaN
# 6           NaN         NaN             NaN            NaN           NaN
# 7           NaN         NaN             NaN            NaN           NaN
# 8           NaN         NaN             NaN            NaN           NaN
# 9           NaN         NaN             NaN            NaN           NaN
#
# [10 rows x 50 columns]
# SUBJECT_ID                   int64
# BIRTH_YEAR                   int64
# GENDER_FACTOR               object
# RACE_FACTOR                 object
# ETHNICITY_FACTOR            object
# PAYER_FACTOR                object
# ATOPIC_MARCH_COHORT           bool
# AGE_START_YEARS            float64
# AGE_END_YEARS              float64
# SHELLFISH_ALG_START        float64
# SHELLFISH_ALG_END          float64
# FISH_ALG_START             float64
# FISH_ALG_END               float64
# MILK_ALG_START             float64
# MILK_ALG_END               float64
# SOY_ALG_START              float64
# SOY_ALG_END                float64
# EGG_ALG_START              float64
# EGG_ALG_END                float64
# WHEAT_ALG_START            float64
# WHEAT_ALG_END              float64
# PEANUT_ALG_START           float64
# PEANUT_ALG_END             float64
# SESAME_ALG_START           float64
# SESAME_ALG_END             float64
# TREENUT_ALG_START          float64
# TREENUT_ALG_END            float64
# WALNUT_ALG_START           float64
# WALNUT_ALG_END             float64
# PECAN_ALG_START            float64
# PECAN_ALG_END              float64
# PISTACH_ALG_START          float64
# PISTACH_ALG_END            float64
# ALMOND_ALG_START           float64
# ALMOND_ALG_END             float64
# BRAZIL_ALG_START           float64
# BRAZIL_ALG_END             float64
# HAZELNUT_ALG_START         float64
# HAZELNUT_ALG_END           float64
# CASHEW_ALG_START           float64
# CASHEW_ALG_END             float64
# ATOPIC_DERM_START          float64
# ATOPIC_DERM_END            float64
# ALLERGIC_RHINITIS_START    float64
# ALLERGIC_RHINITIS_END      float64
# ASTHMA_START               float64
# ASTHMA_END                 float64
# FIRST_ASTHMARX             float64
# LAST_ASTHMARX              float64
# NUM_ASTHMARX               float64
# dtype: object

# %%
# アレルギー疾患の状態を保持の有無のみにする
allergy_data['ATOPIC_DERM_START'] = allergy_data['ATOPIC_DERM_START'].notna()
allergy_data['ALLERGIC_RHINITIS_START'] = allergy_data['ALLERGIC_RHINITIS_START'].notna()
allergy_data['ASTHMA_START'] = allergy_data['ASTHMA_START'].notna()

# %%
# 食物アレルギーを保持の有無のみにする
allergy_data['SHELLFISH_ALG_START'] = allergy_data['SHELLFISH_ALG_START'].notna()
allergy_data['FISH_ALG_START'] = allergy_data['FISH_ALG_START'].notna()
allergy_data['MILK_ALG_START'] = allergy_data['MILK_ALG_START'].notna()
allergy_data['SOY_ALG_START'] = allergy_data['SOY_ALG_START'].notna()
allergy_data['EGG_ALG_START'] = allergy_data['EGG_ALG_START'].notna()
allergy_data['WHEAT_ALG_START'] = allergy_data['WHEAT_ALG_START'].notna()
allergy_data['PEANUT_ALG_START'] = allergy_data['PEANUT_ALG_START'].notna()
allergy_data['SESAME_ALG_START'] = allergy_data['SESAME_ALG_START'].notna()
allergy_data['TREENUT_ALG_START'] = allergy_data['TREENUT_ALG_START'].notna()
allergy_data['WALNUT_ALG_START'] = allergy_data['WALNUT_ALG_START'].notna()
allergy_data['PECAN_ALG_START'] = allergy_data['PECAN_ALG_START'].notna()
allergy_data['PISTACH_ALG_START'] = allergy_data['PISTACH_ALG_START'].notna()
allergy_data['ALMOND_ALG_START'] = allergy_data['ALMOND_ALG_START'].notna()
allergy_data['BRAZIL_ALG_START'] = allergy_data['BRAZIL_ALG_START'].notna()
allergy_data['HAZELNUT_ALG_START'] = allergy_data['HAZELNUT_ALG_START'].notna()
allergy_data['CASHEW_ALG_START'] = allergy_data['CASHEW_ALG_START'].notna()
display(allergy_data['ASTHMA_START'].head(10))
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4    False
# 5    False
# 6    False
# 7    False
# 8    False
# 9    False
# Name: ASTHMA_START, dtype: bool

# %%
# アレルギー疾患と食物アレルギーの有無をダミーデータ化
allergy_data = allergy_data * 1
display(allergy_data)
# Out:
#         SUBJECT_ID  BIRTH_YEAR GENDER_FACTOR   RACE_FACTOR   ETHNICITY_FACTOR  \
# 0                1        2006   S1 - Female    R1 - Black  E0 - Non-Hispanic
# 1                2        1994   S1 - Female    R0 - White  E0 - Non-Hispanic
# 2                3        2006     S0 - Male    R0 - White      E1 - Hispanic
# 3                4        2004     S0 - Male  R4 - Unknown      E1 - Hispanic
# 4                5        2006   S1 - Female    R1 - Black  E0 - Non-Hispanic
# ...            ...         ...           ...           ...                ...
# 333195      333196        2006     S0 - Male    R0 - White  E0 - Non-Hispanic
# 333196      333197        2006   S1 - Female    R1 - Black  E0 - Non-Hispanic
# 333197      333198        2006     S0 - Male    R0 - White  E0 - Non-Hispanic
# 333198      333199        2006     S0 - Male    R3 - Other  E0 - Non-Hispanic
# 333199      333200        2006   S1 - Female    R0 - White  E0 - Non-Hispanic
#
#              PAYER_FACTOR  ATOPIC_MARCH_COHORT  AGE_START_YEARS  \
# 0           P1 - Medicaid                    0         0.093087
# 1       P0 - Non-Medicaid                    0        12.232717
# 2       P0 - Non-Medicaid                    1         0.010951
# 3       P0 - Non-Medicaid                    0         2.398357
# 4       P0 - Non-Medicaid                    0         0.013689
# ...                   ...                  ...              ...
# 333195  P0 - Non-Medicaid                    0         0.736482
# 333196      P1 - Medicaid                    1         0.019165
# 333197  P0 - Non-Medicaid                    0         0.443532
# 333198  P0 - Non-Medicaid                    1         0.013689
# 333199  P0 - Non-Medicaid                    0         0.019165
#
#         AGE_END_YEARS  SHELLFISH_ALG_START  ...  CASHEW_ALG_END  \
# 0            3.164956                    0  ...             NaN
# 1           18.880219                    0  ...             NaN
# 2            6.726899                    0  ...             NaN
# 3            9.111567                    0  ...             NaN
# 4            6.193018                    0  ...             NaN
# ...               ...                  ...  ...             ...
# 333195       7.449692                    0  ...             NaN
# 333196       6.984257                    0  ...             NaN
# 333197       7.405886                    0  ...             NaN
# 333198       7.017112                    0  ...             NaN
# 333199       3.014374                    0  ...             NaN
#
#         ATOPIC_DERM_START  ATOPIC_DERM_END  ALLERGIC_RHINITIS_START  \
# 0                       0              NaN                        0
# 1                       0              NaN                        0
# 2                       1              NaN                        1
# 3                       0              NaN                        0
# 4                       0              NaN                        0
# ...                   ...              ...                      ...
# 333195                  1              NaN                        0
# 333196                  0              NaN                        0
# 333197                  0              NaN                        0
# 333198                  0              NaN                        0
# 333199                  1         0.347707                        0
#
#         ALLERGIC_RHINITIS_END  ASTHMA_START  ASTHMA_END  FIRST_ASTHMARX  \
# 0                         NaN             0         NaN             NaN
# 1                         NaN             0         NaN       12.262834
# 2                    6.157426             1         NaN        1.404517
# 3                         NaN             0         NaN             NaN
# 4                         NaN             0         NaN             NaN
# ...                       ...           ...         ...             ...
# 333195                    NaN             1    7.449692             NaN
# 333196                    NaN             0         NaN             NaN
# 333197                    NaN             1         NaN        2.321697
# 333198                    NaN             0         NaN             NaN
# 333199                    NaN             0         NaN             NaN
#
#         LAST_ASTHMARX  NUM_ASTHMARX
# 0                 NaN           NaN
# 1           18.880219           2.0
# 2            6.157426           4.0
# 3                 NaN           NaN
# 4                 NaN           NaN
# ...               ...           ...
# 333195            NaN           NaN
# 333196            NaN           NaN
# 333197       6.650240           4.0
# 333198            NaN           NaN
# 333199            NaN           NaN
#
# [333200 rows x 50 columns]

# %%
# 相関関係を見たいアレルギー疾患と食物アレルギーのカラムのみにする
food_diag = allergy_data.reindex(columns=['ATOPIC_DERM_START','ALLERGIC_RHINITIS_START', 'ASTHMA_START',
                                          'SHELLFISH_ALG_START', 'FISH_ALG_START','MILK_ALG_START',
                                          'SOY_ALG_START' ,'EGG_ALG_START', 'WHEAT_ALG_START',
                                          'PEANUT_ALG_START', 'SESAME_ALG_START','TREENUT_ALG_START',
                                          'WALNUT_ALG_START' ,'PECAN_ALG_START', 'PISTACH_ALG_START',
                                          'ALMOND_ALG_START', 'BRAZIL_ALG_START','HAZELNUT_ALG_START',
                                          'CASHEW_ALG_START'])

# %%
# アレルギー疾患と食物アレルギーの相関性を見る
food_diag_corr = food_diag.corr()
food_diag_corr
# Out:
#                          ATOPIC_DERM_START  ALLERGIC_RHINITIS_START  \
# ATOPIC_DERM_START                 1.000000                 0.128554
# ALLERGIC_RHINITIS_START           0.128554                 1.000000
# ASTHMA_START                      0.124751                 0.336186
# SHELLFISH_ALG_START               0.070858                 0.082988
# FISH_ALG_START                    0.061779                 0.053603
# MILK_ALG_START                    0.079532                 0.052862
# SOY_ALG_START                     0.062169                 0.050698
# EGG_ALG_START                     0.117883                 0.079832
# WHEAT_ALG_START                   0.052272                 0.042203
# PEANUT_ALG_START                  0.120592                 0.112126
# SESAME_ALG_START                  0.041255                 0.050476
# TREENUT_ALG_START                 0.004147                -0.000775
# WALNUT_ALG_START                  0.027266                 0.030088
# PECAN_ALG_START                   0.018370                 0.020510
# PISTACH_ALG_START                 0.019068                 0.025045
# ALMOND_ALG_START                  0.018513                 0.028787
# BRAZIL_ALG_START                  0.012342                 0.010517
# HAZELNUT_ALG_START                0.012376                 0.023619
# CASHEW_ALG_START                  0.024209                 0.024438
#
#                          ASTHMA_START  SHELLFISH_ALG_START  FISH_ALG_START  \
# ATOPIC_DERM_START            0.124751             0.070858        0.061779
# ALLERGIC_RHINITIS_START      0.336186             0.082988        0.053603
# ASTHMA_START                 1.000000             0.090973        0.055262
# SHELLFISH_ALG_START          0.090973             1.000000        0.212947
# FISH_ALG_START               0.055262             0.212947        1.000000
# MILK_ALG_START               0.058935             0.070416        0.078939
# SOY_ALG_START                0.049330             0.062737        0.078198
# EGG_ALG_START                0.086596             0.129580        0.145430
# WHEAT_ALG_START              0.041584             0.067930        0.071989
# PEANUT_ALG_START             0.118994             0.157160        0.151633
# SESAME_ALG_START             0.047307             0.082528        0.095747
# TREENUT_ALG_START           -0.000844            -0.000219       -0.000128
# WALNUT_ALG_START             0.029231             0.036710        0.027856
# PECAN_ALG_START              0.015483             0.021865        0.013269
# PISTACH_ALG_START            0.019545             0.018985        0.018499
# ALMOND_ALG_START             0.020621             0.021208        0.024002
# BRAZIL_ALG_START             0.011190             0.026886        0.021904
# HAZELNUT_ALG_START           0.018407             0.025397        0.021780
# CASHEW_ALG_START             0.024261             0.028913        0.026970
#
#                          MILK_ALG_START  SOY_ALG_START  EGG_ALG_START  \
# ATOPIC_DERM_START              0.079532       0.062169       0.117883
# ALLERGIC_RHINITIS_START        0.052862       0.050698       0.079832
# ASTHMA_START                   0.058935       0.049330       0.086596
# SHELLFISH_ALG_START            0.070416       0.062737       0.129580
# FISH_ALG_START                 0.078939       0.078198       0.145430
# MILK_ALG_START                 1.000000       0.304290       0.321890
# SOY_ALG_START                  0.304290       1.000000       0.251745
# EGG_ALG_START                  0.321890       0.251745       1.000000
# WHEAT_ALG_START                0.227767       0.276364       0.255060
# PEANUT_ALG_START               0.197982       0.212537       0.373149
# SESAME_ALG_START               0.076789       0.105143       0.139251
# TREENUT_ALG_START              0.011584      -0.000148       0.012723
# WALNUT_ALG_START               0.033333       0.051498       0.057784
# PECAN_ALG_START                0.020188       0.024102       0.042094
# PISTACH_ALG_START              0.025247       0.016285       0.043391
# ALMOND_ALG_START               0.033509       0.060482       0.054101
# BRAZIL_ALG_START               0.017972       0.008678       0.035775
# HAZELNUT_ALG_START             0.022692       0.033578       0.045149
# CASHEW_ALG_START               0.036896       0.040464       0.061215
#
#                          WHEAT_ALG_START  PEANUT_ALG_START  SESAME_ALG_START  \
# ATOPIC_DERM_START               0.052272          0.120592          0.041255
# ALLERGIC_RHINITIS_START         0.042203          0.112126          0.050476
# ASTHMA_START                    0.041584          0.118994          0.047307
# SHELLFISH_ALG_START             0.067930          0.157160          0.082528
# FISH_ALG_START                  0.071989          0.151633          0.095747
# MILK_ALG_START                  0.227767          0.197982          0.076789
# SOY_ALG_START                   0.276364          0.212537          0.105143
# EGG_ALG_START                   0.255060          0.373149          0.139251
# WHEAT_ALG_START                 1.000000          0.181865          0.086022
# PEANUT_ALG_START                0.181865          1.000000          0.216358
# SESAME_ALG_START                0.086022          0.216358          1.000000
# TREENUT_ALG_START              -0.000102          0.010610          0.036090
# WALNUT_ALG_START                0.045303          0.105913          0.079677
# PECAN_ALG_START                 0.017570          0.072682          0.090771
# PISTACH_ALG_START               0.024246          0.064348          0.066231
# ALMOND_ALG_START                0.040195          0.093737          0.083108
# BRAZIL_ALG_START                0.020693          0.057115          0.065120
# HAZELNUT_ALG_START              0.031880          0.086613          0.069203
# CASHEW_ALG_START                0.031348          0.105141          0.077511
#
#                          TREENUT_ALG_START  WALNUT_ALG_START  PECAN_ALG_START  \
# ATOPIC_DERM_START                 0.004147          0.027266         0.018370
# ALLERGIC_RHINITIS_START          -0.000775          0.030088         0.020510
# ASTHMA_START                     -0.000844          0.029231         0.015483
# SHELLFISH_ALG_START              -0.000219          0.036710         0.021865
# FISH_ALG_START                   -0.000128          0.027856         0.013269
# MILK_ALG_START                    0.011584          0.033333         0.020188
# SOY_ALG_START                    -0.000148          0.051498         0.024102
# EGG_ALG_START                     0.012723          0.057784         0.042094
# WHEAT_ALG_START                  -0.000102          0.045303         0.017570
# PEANUT_ALG_START                  0.010610          0.105913         0.072682
# SESAME_ALG_START                  0.036090          0.079677         0.090771
# TREENUT_ALG_START                 1.000000         -0.000080        -0.000051
# WALNUT_ALG_START                 -0.000080          1.000000         0.322847
# PECAN_ALG_START                  -0.000051          0.322847         1.000000
# PISTACH_ALG_START                -0.000058          0.141925         0.156446
# ALMOND_ALG_START                 -0.000059          0.179050         0.134814
# BRAZIL_ALG_START                 -0.000025          0.109161         0.121763
# HAZELNUT_ALG_START               -0.000048          0.221783         0.207910
# CASHEW_ALG_START                 -0.000071          0.167101         0.171580
#
#                          PISTACH_ALG_START  ALMOND_ALG_START  \
# ATOPIC_DERM_START                 0.019068          0.018513
# ALLERGIC_RHINITIS_START           0.025045          0.028787
# ASTHMA_START                      0.019545          0.020621
# SHELLFISH_ALG_START               0.018985          0.021208
# FISH_ALG_START                    0.018499          0.024002
# MILK_ALG_START                    0.025247          0.033509
# SOY_ALG_START                     0.016285          0.060482
# EGG_ALG_START                     0.043391          0.054101
# WHEAT_ALG_START                   0.024246          0.040195
# PEANUT_ALG_START                  0.064348          0.093737
# SESAME_ALG_START                  0.066231          0.083108
# TREENUT_ALG_START                -0.000058         -0.000059
# WALNUT_ALG_START                  0.141925          0.179050
# PECAN_ALG_START                   0.156446          0.134814
# PISTACH_ALG_START                 1.000000          0.097015
# ALMOND_ALG_START                  0.097015          1.000000
# BRAZIL_ALG_START                  0.157452          0.104515
# HAZELNUT_ALG_START                0.205465          0.162416
# CASHEW_ALG_START                  0.313370          0.149242
#
#                          BRAZIL_ALG_START  HAZELNUT_ALG_START  \
# ATOPIC_DERM_START                0.012342            0.012376
# ALLERGIC_RHINITIS_START          0.010517            0.023619
# ASTHMA_START                     0.011190            0.018407
# SHELLFISH_ALG_START              0.026886            0.025397
# FISH_ALG_START                   0.021904            0.021780
# MILK_ALG_START                   0.017972            0.022692
# SOY_ALG_START                    0.008678            0.033578
# EGG_ALG_START                    0.035775            0.045149
# WHEAT_ALG_START                  0.020693            0.031880
# PEANUT_ALG_START                 0.057115            0.086613
# SESAME_ALG_START                 0.065120            0.069203
# TREENUT_ALG_START               -0.000025           -0.000048
# WALNUT_ALG_START                 0.109161            0.221783
# PECAN_ALG_START                  0.121763            0.207910
# PISTACH_ALG_START                0.157452            0.205465
# ALMOND_ALG_START                 0.104515            0.162416
# BRAZIL_ALG_START                 1.000000            0.190299
# HAZELNUT_ALG_START               0.190299            1.000000
# CASHEW_ALG_START                 0.158281            0.195530
#
#                          CASHEW_ALG_START
# ATOPIC_DERM_START                0.024209
# ALLERGIC_RHINITIS_START          0.024438
# ASTHMA_START                     0.024261
# SHELLFISH_ALG_START              0.028913
# FISH_ALG_START                   0.026970
# MILK_ALG_START                   0.036896
# SOY_ALG_START                    0.040464
# EGG_ALG_START                    0.061215
# WHEAT_ALG_START                  0.031348
# PEANUT_ALG_START                 0.105141
# SESAME_ALG_START                 0.077511
# TREENUT_ALG_START               -0.000071
# WALNUT_ALG_START                 0.167101
# PECAN_ALG_START                  0.171580
# PISTACH_ALG_START                0.313370
# ALMOND_ALG_START                 0.149242
# BRAZIL_ALG_START                 0.158281
# HAZELNUT_ALG_START               0.195530
# CASHEW_ALG_START                 1.000000

# %%
# 見やすい様にカラムの順序を変更する
food_diag_corr = food_diag_corr.reindex(columns=['SHELLFISH_ALG_START', 'FISH_ALG_START','MILK_ALG_START',
                                                 'SOY_ALG_START' ,'EGG_ALG_START', 'WHEAT_ALG_START',
                                                 'PEANUT_ALG_START', 'SESAME_ALG_START','WALNUT_ALG_START' ,
                                                 'PECAN_ALG_START', 'PISTACH_ALG_START','ALMOND_ALG_START', 
                                                 'BRAZIL_ALG_START','HAZELNUT_ALG_START','CASHEW_ALG_START'],
                                        index=['ATOPIC_DERM_START','ALLERGIC_RHINITIS_START', 'ASTHMA_START'])

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import japanize_matplotlib

# 文字化けするので、フォントを指定
sns.set_theme(font_scale=1, font='IPAexGothic')

# %%
# カラム量が多いため、サイズを見やすく調整
fig, ax = plt.subplots(figsize=(6, 6)) 

# ヒートマップで可視化
plt.tight_layout()
sns.heatmap(food_diag_corr, cmap="Blues", square=True)

results_path = '../Graphs/corr_food_diag.png'
# plt.savefig(results_path, bbox_inches='tight')

# %%
# 分析結果
# ゴマと木の実類アレルギーはデータ数が少なく、相関性も薄い。
# 小麦はデータ数は一定数あるが、疾患との相関関係は薄い。
# ピーナッツはアトピー、鼻炎、喘息と全てにおいて相関性が強い。
# 卵アレルギーとアトピーとの相関性が強い。
# 喘息と甲殻類との相関性が強い。

# %%
# それぞれの疾患の保持者者のみを抽出
Atopic = allergy_data[allergy_data['ATOPIC_DERM_START'] == True]
Rhinitis = allergy_data[allergy_data['ALLERGIC_RHINITIS_START'] == True]
Athma = allergy_data[allergy_data['ASTHMA_START'] == True]
display(Rhinitis.head(10))
# Out:
#     SUBJECT_ID  BIRTH_YEAR GENDER_FACTOR RACE_FACTOR   ETHNICITY_FACTOR  \
# 2            3        2006     S0 - Male  R0 - White      E1 - Hispanic
# 23          24        1999   S1 - Female  R0 - White  E0 - Non-Hispanic
# 27          28        1999   S1 - Female  R0 - White  E0 - Non-Hispanic
# 34          35        2005   S1 - Female  R0 - White  E0 - Non-Hispanic
# 44          45        2006     S0 - Male  R0 - White  E0 - Non-Hispanic
# 67          68        2004     S0 - Male  R0 - White  E0 - Non-Hispanic
# 71          72        2006     S0 - Male  R1 - Black  E0 - Non-Hispanic
# 76          77        2006     S0 - Male  R1 - Black  E0 - Non-Hispanic
# 77          78        2005     S0 - Male  R0 - White  E0 - Non-Hispanic
# 78          79        2006     S0 - Male  R0 - White  E0 - Non-Hispanic
#
#          PAYER_FACTOR  ATOPIC_MARCH_COHORT  AGE_START_YEARS  AGE_END_YEARS  \
# 2   P0 - Non-Medicaid                    1         0.010951       6.726899
# 23  P0 - Non-Medicaid                    0         7.783710      14.704997
# 27  P0 - Non-Medicaid                    0         7.581109      14.398357
# 34  P0 - Non-Medicaid                    0         1.760438       7.764545
# 44  P0 - Non-Medicaid                    0         0.591376       7.126626
# 67  P0 - Non-Medicaid                    0         2.568104       7.126626
# 71      P1 - Medicaid                    0         0.183436       7.030801
# 76  P0 - Non-Medicaid                    1         0.038330       6.053388
# 77  P0 - Non-Medicaid                    0         1.357974       8.043806
# 78  P0 - Non-Medicaid                    0         0.013689       7.063655
#
#     SHELLFISH_ALG_START  ...  CASHEW_ALG_END  ATOPIC_DERM_START  \
# 2                     0  ...             NaN                  1
# 23                    0  ...             NaN                  0
# 27                    0  ...             NaN                  0
# 34                    0  ...             NaN                  0
# 44                    0  ...             NaN                  0
# 67                    0  ...             NaN                  0
# 71                    0  ...             NaN                  1
# 76                    0  ...             NaN                  0
# 77                    1  ...             NaN                  1
# 78                    0  ...             NaN                  1
#
#     ATOPIC_DERM_END  ALLERGIC_RHINITIS_START  ALLERGIC_RHINITIS_END  \
# 2               NaN                        1               6.157426
# 23              NaN                        1              13.445585
# 27              NaN                        1              11.791923
# 34              NaN                        1                    NaN
# 44              NaN                        1               3.066393
# 67              NaN                        1                    NaN
# 71              NaN                        1                    NaN
# 76              NaN                        1                    NaN
# 77              NaN                        1                    NaN
# 78         0.394251                        1                    NaN
#
#     ASTHMA_START  ASTHMA_END  FIRST_ASTHMARX  LAST_ASTHMARX  NUM_ASTHMARX
# 2              1         NaN        1.404517       6.157426           4.0
# 23             0         NaN        7.783710      11.950719           4.0
# 27             0         NaN             NaN            NaN           NaN
# 34             0         NaN             NaN            NaN           NaN
# 44             0         NaN        1.037645       5.705681           6.0
# 67             0         NaN             NaN            NaN           NaN
# 71             1         NaN        4.052019       4.052019           1.0
# 76             1         NaN        1.963039       5.420945           5.0
# 77             1    8.068446        3.290897       8.068446           6.0
# 78             0         NaN        4.208077       4.208077           1.0
#
# [10 rows x 50 columns]

# %%
# AtopicShell = allergy_data[allergy_data['ATOPIC_DERM_START'] == True]
# display(AtopicShell.head(10))
