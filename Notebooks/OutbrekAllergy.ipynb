# %%
import pandas as pd

allergy_data = pd.read_csv('../Data/race_sample.csv')
display(allergy_data.head(10))
allergy_data.shape
allergy_data.dtypes
# Out:
#    SUBJECT_ID  BIRTH_YEAR GENDER_FACTOR RACE_FACTOR   ETHNICITY_FACTOR  \
# 0      256086        2001     S0 - Male       Asian  E0 - Non-Hispanic
# 1       48892        2006   S1 - Female       Asian  E0 - Non-Hispanic
# 2      264558        1990     S0 - Male       Asian  E0 - Non-Hispanic
# 3       70323        1997     S0 - Male       Asian  E0 - Non-Hispanic
# 4       31931        2007     S0 - Male       Asian  E0 - Non-Hispanic
# 5      296184        2000   S1 - Female       Asian  E0 - Non-Hispanic
# 6      301397        2005     S0 - Male       Asian  E0 - Non-Hispanic
# 7      272297        1993   S1 - Female       Asian  E0 - Non-Hispanic
# 8       87279        2010     S0 - Male       Asian  E0 - Non-Hispanic
# 9      276306        1994   S1 - Female       Asian  E0 - Non-Hispanic
#
#         PAYER_FACTOR  ATOPIC_MARCH_COHORT  AGE_START_YEARS  AGE_END_YEARS  \
# 0  P0 - Non-Medicaid                False         2.913073       9.185489
# ...

# %%
# 異常値を含まないデータを抽出する
mean = allergy_data['SHELLFISH_ALG_START'].mean()
std = allergy_data['SHELLFISH_ALG_START'].std()
threshold = mean + 3 * std
outliers = allergy_data[allergy_data['SHELLFISH_ALG_START'] > threshold]
shellfish = allergy_data[allergy_data['SHELLFISH_ALG_START'] <= threshold]

# %%
# それぞれのアレルゲンの発症年齢を出す
# NAを削除
shellfish = allergy_data.dropna(subset=['SHELLFISH_ALG_START'])
# shellfish = shellfish.loc[:, ['SHELLFISH_ALG_START']]
# shellfish.to_csv('../Data/shellfish.csv', mode='w', index=False)
unique_list = shellfish["SHELLFISH_ALG_START"].unique()
print("一意の「shellfish」リスト\n", unique_list)

# shellfish['SHELLFISH_ALG_START'].astype(int)
# shellfish['SHELLFISH_ALG_START'] = shellfish['SHELLFISH_ALG_START'].replace('nan','NA')
# shellfish = shellfish.dropna()
# unique_list = allergy_data["SHELLFISH_ALG_START"].unique()
# print("一意の「shellfish」リスト\n", unique_list)
# fish = allergy_data[allergy_data['FISH_ALG_START'] == True]
# milk = allergy_data[allergy_data['MILK_ALG_START'] == True]
# soy = allergy_data[allergy_data['SOY_ALG_START'] == True]
# egg = allergy_data[allergy_data['EGG_ALG_START'] == True]
# wheat = allergy_data[allergy_data['WHEAT_ALG_START'] == True]
# peanut = allergy_data[allergy_data['PEANUT_ALG_START'] == True]
# sesami = allergy_data[allergy_data['SESAME_ALG_START'] == True]
# treenut = allergy_data[allergy_data['TREENUT_ALG_START'] == True]
# wallnut = allergy_data[allergy_data['WALNUT_ALG_START'] == True]
# pecan = allergy_data[allergy_data['PECAN_ALG_START'] == True]
# psitach = allergy_data[allergy_data['PISTACH_ALG_START'] == True]
# almond = allergy_data[allergy_data['ALMOND_ALG_START'] == True]
# brazil = allergy_data[allergy_data['BRAZIL_ALG_START'] == True]
# hazel = allergy_data[allergy_data['HAZELNUT_ALG_START'] == True]
# cashew = allergy_data[allergy_data['CASHEW_ALG_START'] == True]
# shellfish.dtype
# Out:
# 一意の「shellfish」リスト
#  [ 1.5742642   2.98425736  5.77412731  1.52772074 15.90691307  7.55373032
#   1.49212868  5.05407255  7.60848734  7.77275838  3.03627652  5.21013005
#   0.64065708 11.42231348  3.56741958  2.01232033  3.85489391  4.
#   3.09650924  7.27720739  4.03285421  1.26214921  6.4476386   8.86516085
#   1.25393566  1.24572211 13.56057495  8.32032854  1.03764545  4.14510609
#   2.41752225  6.47775496  1.84257358  6.65845311  1.09787817  6.1026694
#   2.28884326  4.69815195  5.08145106  0.3340178  11.6605065   6.80355921
#   2.66119097 10.52977413  2.76249144  3.14031485  2.05065024  6.54620123
#   4.65434634 14.17932923  7.72073922 16.04106776  4.38329911  9.24572211
#   5.49212868  9.87816564  2.37645448 11.33744011  1.09240246  9.59616701
#  14.13826146  3.12388775  1.06776181 13.83162218 13.16084873  4.29295003
#   9.76043806  9.47570157  3.79739904  5.68104038 17.59890486  4.1670089
#   1.5523614   4.70910335  2.86926762  1.40999316 10.92128679 10.04791239
# ...

# %%
# cols = allergy_data.columns.drop(['GENDER_FACTOR', 'RACE_FACTOR', 'ETHNICITY_FACTOR', 'PAYER_FACTOR', 'ATOPIC_MARCH_COHORT'])
# allergy_data[cols] = allergy_data[cols].apply(pd.to_numeric, errors='coerce', downcast='integer')

# allergy_data[['SHELLFISH_ALG_START', 'FISH_ALG_START','MILK_ALG_START', 'SOY_ALG_START',
#               'EGG_ALG_START', 'WHEAT_ALG_START','PEANUT_ALG_START', 'SESAME_ALG_START',
#               'TREENUT_ALG_START', 'WALNUT_ALG_START','PECAN_ALG_START', 'PISTACH_ALG_START',
#               'ALMOND_ALG_START', 'BRAZIL_ALG_START','HAZELNUT_ALG_START', 'CASHEW_ALG_START'
#              ]] = allergy_data[['SHELLFISH_ALG_START', 'FISH_ALG_START','MILK_ALG_START', 'SOY_ALG_START',
#               'EGG_ALG_START', 'WHEAT_ALG_START','PEANUT_ALG_START', 'SESAME_ALG_START',
#               'TREENUT_ALG_START', 'WALNUT_ALG_START','PECAN_ALG_START', 'PISTACH_ALG_START',
#               'ALMOND_ALG_START', 'BRAZIL_ALG_START','HAZELNUT_ALG_START', 'CASHEW_ALG_START'
#                ]].apply(pd.to_numeric, errors='coerce', downcast='integer')
shellfish['SHELLFISH_ALG_START'] = pd.to_numeric(shellfish['SHELLFISH_ALG_START'], errors='coerce', downcast='integer')
shellfish'SHELLFISH_ALG_START'].dtype
# Out:
# /var/folders/5d/b7fwtkfx04x29cf5dnldt0kw0000gn/T/ipykernel_10864/963956425.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shellfish['SHELLFISH_ALG_START'] = pd.to_numeric(shellfish['SHELLFISH_ALG_START'], errors='coerce', downcast='integer')
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/5d/b7fwtkfx04x29cf5dnldt0kw0000gn/T/ipykernel_10864/963956425.py in <module>
#      12 #                ]].apply(pd.to_numeric, errors='coerce', downcast='integer')
#      13 shellfish['SHELLFISH_ALG_START'] = pd.to_numeric(shellfish['SHELLFISH_ALG_START'], errors='coerce', downcast='integer')
# ---> 14 shellfish.dtype
#
# ...
